# %%
#This script analyzed the 25 most frequently occured words in body column in post.csv

# %%
#first install nltk
! pip install -U nltk
# Out:
# ...
#     100% |████████████████████████████████| 1.2MB 831kB/s ta 0:00:01
# ...
#   Using cached six-1.11.0-py2.py3-none-any.whl
# ...
#   Running setup.py bdist_wheel for nltk ... done
#   Stored in directory: /Users/xinyun/Library/Caches/pip/wheels/18/9c/1f/276bc3f421614062468cb1c9d695e6086d0c73d67ea363c501
# Successfully built nltk
# ...
#   Found existing installation: six 1.10.0
#     Uninstalling six-1.10.0:
#       Successfully uninstalled six-1.10.0
#   Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
# ...

# %%
#download nltk documents for further use
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import pandas as pd
# %pwd
# Out:
# '/Users/xinyun/Desktop/Python'

# %%
#load data
posts = pd.read_csv("Data/posts.csv", encoding = 'utf-8')
posts.head
# Out:
# <bound method NDFrame.head of           Id  PostTypeId  AcceptedAnswerId    ParentId         CreationDate  \
# 0   31133870           1        40365282.0         NaN  2015-06-30 09:00:22
# 1   31133871           2               NaN  15711499.0  2015-06-30 09:00:22
# 2   31133872           1        31133998.0         NaN  2015-06-30 09:00:25
# 3   31133873           1        31340092.0         NaN  2015-06-30 09:00:37
# 4   31133874           2               NaN  16454499.0  2015-06-30 09:00:39
# 5   31133875           1        31134112.0         NaN  2015-06-30 09:00:45
# 6   31133877           2               NaN  31133416.0  2015-06-30 09:00:49
# 7   31133878           1        31134265.0         NaN  2015-06-30 09:00:49
# 8   31133879           2               NaN  31132988.0  2015-06-30 09:00:50
# 9   31133880           2               NaN  31133546.0  2015-06-30 09:00:51
# 10  31133881           2               NaN  31133557.0  2015-06-30 09:00:55
# ...

# %%
# First get all the post body text into one big block
body = posts.Body.str.cat(sep=' ')
print(body)
# Out:
# <p>First of all I'm not actually sure if this belongs to CrossValidated or to StackOverflow. I'm sorry if I posted this Question on the wrong site.</p>
#
# <p>I'm comparing several datasets against an observational dataset using R. Each of these has about 10 million continuous float values (the length of the data vector is not exactly the same for each dataset).</p>
#
# <p>I usually calculate the <strong>Kolmogorov-Smirnov</strong> statistic using the <code>ks.test()</code> function from the standard <code>stats</code> package, but now I'm especially interested in the extreme values of the distributions. The KS, as far as I understand, pretty much hides those. The same happens for the <strong>Kullback-Leibler</strong> (feel free to correct me if I'm wrong).</p>
#
# ...

# %%
table = {
    ord(u'\u2018') : u"'",
    ord(u'\u2019') : u"'",
    ord(u'\u201C') : u'"',
    ord(u'\u201d') : u'"',
    ord(u'\u2026') : u' ', 
    ord(u'\u2014') : u' ', # get rid of em dashes
}
body = body.translate(table)
#body
# Out:
# '<p>First of all I\'m not actually sure if this belongs to CrossValidated or to StackOverflow. I\'m sorry if I posted this Question on the wrong site.</p>\n\n<p>I\'m comparing several datasets against an observational dataset using R. Each of these has about 10 million continuous float values (the length of the data vector is not exactly the same for each dataset).</p>\n\n<p>I usually calculate the <strong>Kolmogorov-Smirnov</strong> statistic using the <code>ks.test()</code> function from the standard <code>stats</code> package, but now I\'m especially interested in the extreme values of the distributions. The KS, as far as I understand, pretty much hides those. The same happens for the <strong>Kullback-Leibler</strong> (feel free to correct me if I\'m wrong).</p>\n\n<p>The <strong>Anderson-Darling</strong> test, on the other hand, is weighted to take into account the extremes of the distributions. However, I\'ve not been able to find a simple implementation of the AD test that work
# ...

# %%
#remove punctuation
import string

def remove_punctuation(text):
    # Grab the list of standard punctuation symbols that are provided in the string library
    punctuations = string.punctuation # includes following characters: !"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~

    # But don't strip out apostrophes, as we want to preserve possessives and contractions, an alternative would be to expand contractions
    excluded_punctuations = ["'"]
    for p in punctuations:
        if p not in excluded_punctuations:
            # replace each punctuation symbol by a space
            text = text.replace(p, " ") 

    return text

body = remove_punctuation(body)

# %%
" ".join(body.split())
# Out:
# "p First of all I'm not actually sure if this belongs to CrossValidated or to StackOverflow I'm sorry if I posted this Question on the wrong site p p I'm comparing several datasets against an observational dataset using R Each of these has about 10 million continuous float values the length of the data vector is not exactly the same for each dataset p p I usually calculate the strong Kolmogorov Smirnov strong statistic using the code ks test code function from the standard code stats code package but now I'm especially interested in the extreme values of the distributions The KS as far as I understand pretty much hides those The same happens for the strong Kullback Leibler strong feel free to correct me if I'm wrong p p The strong Anderson Darling strong test on the other hand is weighted to take into account the extremes of the distributions However I've not been able to find a simple implementation of the AD test that works on just two vectors as input as code stats ks test code do
# ...

# %%
from nltk.tokenize import WhitespaceTokenizer

# Create a tokenizer from NLTK which will create tokens based on the whitespace in between words
tokenizer = WhitespaceTokenizer()

# Use the tokenizer on the text string for the transcript
body_tokens = tokenizer.tokenize(body.lower())
#body_tokens
# Out:
# ['p',
#  'first',
#  'of',
#  'all',
#  "i'm",
#  'not',
#  'actually',
#  'sure',
#  'if',
#  'this',
#  'belongs',
#  'to',
#  'crossvalidated',
#  'or',
#  'to',
#  'stackoverflow',
#  "i'm",
#  'sorry',
#  'if',
#  'i',
#  'posted',
#  'this',
#  'question',
#  'on',
#  'the',
#  'wrong',
#  'site',
#  'p',
#  'p',
#  "i'm",
#  'comparing',
#  'several',
#  'datasets',
#  'against',
#  'an',
#  'observational',
#  'dataset',
#  'using',
#  'r',
#  'each',
#  'of',
#  'these',
#  'has',
#  'about',
#  '10',
#  'million',
#  'continuous',
#  'float',
#  'values',
#  'the',
#  'length',
#  'of',
#  'the',
#  'data',
#  'vector',
#  'is',
#  'not',
#  'exactly',
#  'the',
#  'same',
#  'for',
#  'each',
#  'dataset',
#  'p',
#  'p',
#  'i',
#  'usually',
#  'calculate',
#  'the',
#  'strong',
#  'kolmogorov',
#  'smirnov',
#  'strong',
#  'statistic',
#  'using',
#  'the',
#  'code',
#  'ks',
#  'test',
#  'code',
#  'function',
#  'from',
#  'the',
#  'standard',
#  'code',
# ...

# %%
from nltk.corpus import stopwords
stopword_list = stopwords.words('english')
body_tokens = [w for w in body_tokens if w not in stopword_list]

# %%
from nltk.probability import FreqDist

# Construct the distribution (it will count the number of occurrances of each unique token)
frequency_distribution = FreqDist(body_tokens)
frequency_distribution.most_common(25)
# Out:
# [('p', 825),
#  ('code', 680),
#  ('gt', 314),
#  ('pre', 296),
#  ('lt', 242),
#  ('0', 119),
#  ('1', 107),
#  ('li', 90),
#  ('strong', 79),
#  ("'", 76),
#  ('d3', 66),
#  ('name', 65),
#  ('2', 65),
#  ('d1', 57),
#  ('d2', 57),
#  ('d4', 57),
#  ('com', 53),
#  ('http', 52),
#  ('class', 50),
#  ('data', 47),
#  ('function', 47),
#  ('a2', 47),
#  ('id', 46),
#  ('a1', 46),
#  ('a3', 46)]

# %%
#p can be ignored
